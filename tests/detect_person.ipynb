# %%
import cv2
import face_recognition as fr
import matplotlib.pyplot as plt

# %%
img = cv2.imread('./imgs/Elon_Musk.jpg')
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_encoding = fr.face_encodings(rgb_img)[0]

#cv2.imshow('image', img)
#cv2.waitKey(0)

plt.imshow(rgb_img)

# %%
img2 = cv2.imread('./imgs/Elon_Musk.jpg')
rgb_img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
img_encoding2 = fr.face_encodings(rgb_img2)[0]

#cv2.imshow('image', img)
#cv2.waitKey(0)

plt.imshow(rgb_img2)

# %% [markdown]
# Vamos ver se img e img2 são a mesma pessoa

# %%
result = fr.compare_faces([img_encoding], img_encoding2)

print(result)
# Out:
# [True]
